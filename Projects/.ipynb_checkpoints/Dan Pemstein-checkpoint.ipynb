# %%
import pandas as pd
import pingouin
import statsmodels.api as sm
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

data = pd.read_csv("conjoint.csv")
keys= list(data.keys())
data["Money"]= data["Money"].astype(int)
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# C:\ProgramData\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.10, the latest is 0.3.12.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
#                                              ID  Money   Jobs  Schools  \
# 0     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0   True    False
# 1     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0   True    False
# 2     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0  False     True
# 3     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      1  False    False
# 4     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      0   True    False
# 5     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      0   True     True
# 6     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0   True    False
# 7     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0   True    False
# 8     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0   True    False
# 9     uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0  False     True
# 10    uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0  False    False
# 11    uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0  False    False
# 12    uuid:a01cc495-f911-4d23-938a-19c615307b50      1  False    False
# 13    uuid:a01cc495-f911-4d23-938a-19c615307b50      0  False    False
# 14    uuid:a01cc495-f911-4d23-938a-19c615307b50      1  False     True
# 15    uuid:e5f7ba88-c0c4-4b02-8d7d-d83b9bf97703      0   True     True
# 16    uuid:e5f7ba88-c0c4-4b02-8d7d-d83b9bf97703      0  False     True
# 17    uuid:e5f7ba88-c0c4-4b02-8d7d-d83b9bf97703      1  False    False
# 18    uuid:6e8dc34e-5921-4b9d-9465-a4d9335bb883      0  False    False
# 19    uuid:6e8dc34e-5921-4b9d-9465-a4d9335bb883      0  False     True
# 20    uuid:6e8dc34e-5921-4b9d-9465-a4d9335bb883      0  False     True
# 21    uuid:d37eabf1-1b61-48cf-9a62-8d9ec6cb365d      0   True    False
# 22    uuid:d37eabf1-1b61-48cf-9a62-8d9ec6cb365d      1  False     True
# 23    uuid:d37eabf1-1b61-48cf-9a62-8d9ec6cb365d      1  False     True
# 24    uuid:bcbc57f0-7e1c-4652-b0b8-a58b8e3c9419      0  False     True
# 25    uuid:bcbc57f0-7e1c-4652-b0b8-a58b8e3c9419      1  False     True
# 26    uuid:f3f753bb-23f6-4700-acaa-ef66aa4c33da      0   True    False
# 27    uuid:f3f753bb-23f6-4700-acaa-ef66aa4c33da      0   True    False
# 28    uuid:f3f753bb-23f6-4700-acaa-ef66aa4c33da      0   True    False
# 29    uuid:c6e78f95-84fa-4db9-9afe-6fd6e4a3c9c7      0  False     True
# ...                                         ...    ...    ...      ...
# 7106  uuid:f0a78f93-e5e1-4e7d-ae69-1c576b35f3d9      1  False    False
# 7107  uuid:83c592ec-4c9b-4c4d-97df-5f5ca14f77d7      0  False     True
# 7108  uuid:83c592ec-4c9b-4c4d-97df-5f5ca14f77d7      0   True     True
# 7109  uuid:d5de7ffe-ed24-49eb-b53e-f6c912f44b21      0   True    False
# 7110  uuid:fdba64d2-ba4c-4fbc-b3a5-31b18f3f2ec0      0   True    False
# 7111  uuid:fdba64d2-ba4c-4fbc-b3a5-31b18f3f2ec0      0   True     True
# 7112  uuid:247b0146-feb5-4c71-a0d0-b3a495bf7ac8      0  False    False
# 7113  uuid:247b0146-feb5-4c71-a0d0-b3a495bf7ac8      0  False    False
# 7114  uuid:247b0146-feb5-4c71-a0d0-b3a495bf7ac8      0   True    False
# 7115  uuid:198793b5-ecce-4866-9dc0-bfb5f88ca8d2      0  False    False
# 7116  uuid:198793b5-ecce-4866-9dc0-bfb5f88ca8d2      0  False    False
# 7117  uuid:2f030846-03f8-4d94-89e5-b20972bc5aa0      0   True     True
# 7118  uuid:2f030846-03f8-4d94-89e5-b20972bc5aa0      0   True     True
# 7119  uuid:b2f329db-c75e-42b1-a3e4-56cc07394f87      0  False     True
# 7120  uuid:b2f329db-c75e-42b1-a3e4-56cc07394f87      0   True    False
# 7121  uuid:b2f329db-c75e-42b1-a3e4-56cc07394f87      0   True    False
# 7122  uuid:7ebe6969-c785-4938-bd5b-f0c40eec8325      0   True    False
# 7123  uuid:7ebe6969-c785-4938-bd5b-f0c40eec8325      0   True    False
# 7124  uuid:e8430af5-af05-43e9-a393-b4e81f85b9cb      0  False     True
# 7125  uuid:e8430af5-af05-43e9-a393-b4e81f85b9cb      0  False    False
# 7126  uuid:e8430af5-af05-43e9-a393-b4e81f85b9cb      0  False    False
# 7127  uuid:9e649795-85c1-48f4-a1bf-4d7e6edfa69e      0  False    False
# 7128  uuid:9e649795-85c1-48f4-a1bf-4d7e6edfa69e      0  False    False
# 7129  uuid:9e649795-85c1-48f4-a1bf-4d7e6edfa69e      0  False     True
# 7130  uuid:55c621ca-102d-4fef-afe5-f8ab3a25bf77      0  False    False
# 7131  uuid:55c621ca-102d-4fef-afe5-f8ab3a25bf77      0  False    False
# 7132  uuid:55c621ca-102d-4fef-afe5-f8ab3a25bf77      0   True     True
# 7133  uuid:e0559fe7-f364-424f-a961-74fce27e157b      0  False     True
# 7134  uuid:e0559fe7-f364-424f-a961-74fce27e157b      0  False    False
# 7135  uuid:e0559fe7-f364-424f-a961-74fce27e157b      0  False     True
#
#             Party  Woman  WomanStrong  vote.choice  client.choice  \
# 0        my-party   True        False         True          False
# 1        my-party  False         True         True          False
# 2     rival-party   True         True        False           True
# 3     rival-party  False        False         True          False
# 4     rival-party   True        False         True          False
# 5     rival-party   True        False         True          False
# 6     rival-party  False        False        False           True
# 7     rival-party  False        False        False           True
# 8     rival-party  False         True        False           True
# 9        my-party  False         True         True          False
# 10       my-party  False        False         True           True
# 11    rival-party  False         True        False           True
# 12       my-party  False         True        False           True
# 13       my-party   True         True         True          False
# 14    rival-party   True        False        False           True
# 15       my-party  False         True         True          False
# 16    rival-party  False         True         True          False
# 17    rival-party  False        False        False           True
# 18    rival-party  False         True        False           True
# 19       my-party   True         True         True          False
# 20    rival-party   True         True         True          False
# 21    rival-party  False         True        False          False
# 22       my-party   True        False        False           True
# 23    rival-party   True        False        False           True
# 24       my-party   True         True         True          False
# 25       my-party  False         True        False           True
# 26    rival-party  False         True         True          False
# 27       my-party   True         True        False           True
# 28       my-party   True         True        False          False
# 29    rival-party  False         True         True          False
# ...           ...    ...          ...          ...            ...
# 7106     my-party  False        False        False           True
# 7107     my-party   True        False        False           True
# 7108     my-party   True        False        False           True
# 7109  rival-party   True         True        False           True
# 7110     my-party  False         True        False           True
# 7111  rival-party  False         True         True          False
# 7112     my-party   True         True         True          False
# 7113     my-party   True         True         True          False
# 7114  rival-party   True         True         True          False
# 7115     my-party   True        False        False           True
# 7116  rival-party   True        False         True          False
# 7117     my-party   True        False        False           True
# 7118  rival-party   True        False         True           True
# 7119  rival-party  False        False         True          False
# 7120  rival-party   True         True        False           True
# 7121  rival-party   True         True        False           True
# 7122  rival-party  False         True        False          False
# 7123  rival-party  False         True        False           True
# 7124  rival-party  False         True         True          False
# 7125  rival-party   True         True         True          False
# 7126     my-party  False         True         True          False
# 7127     my-party  False         True         True           True
# 7128  rival-party   True        False        False          False
# 7129     my-party   True        False         True          False
# 7130     my-party   True         True         True          False
# 7131     my-party   True         True         True          False
# 7132  rival-party  False        False         True           True
# 7133  rival-party   True         True         True          False
# 7134  rival-party   True        False        False          False
# 7135  rival-party   True         True         True          False
#
#       water.choice  school.choice    Wealth   PolPart Vignette2 played.game
# 0             True           True -1.145425  0.422486      Less         Yes
# 1             True           True -1.145425  0.422486      Less         Yes
# 2            False          False -1.145425  0.422486      Less         Yes
# 3             True           True -0.586261  0.095536      Less         Yes
# 4             True           True -0.586261  0.095536      Less         Yes
# 5             True           True -0.586261  0.095536      Less         Yes
# 6            False          False -0.808305  0.186920      Less         Yes
# 7             True          False -0.808305  0.186920      Less         Yes
# 8            False          False -0.808305  0.186920      Less         Yes
# 9             True           True -0.817492  1.064700      More         Yes
# 10            True           True -0.817492  1.064700      More         Yes
# 11           False          False -0.817492  1.064700      More         Yes
# 12           False           True -1.187624  0.613881      Less          No
# 13            True           True -1.187624  0.613881      Less          No
# 14           False           True -1.187624  0.613881      Less          No
# 15            True           True -0.751940 -0.187525      More         Yes
# 16            True           True -0.751940 -0.187525      More         Yes
# 17           False          False -0.751940 -0.187525      More         Yes
# 18           False          False -0.846852  1.071907      Less         Yes
# 19            True           True -0.846852  1.071907      Less         Yes
# 20            True           True -0.846852  1.071907      Less         Yes
# 21            True          False -0.820762 -0.540140      More         Yes
# 22           False          False -0.820762 -0.540140      More         Yes
# 23           False           True -0.820762 -0.540140      More         Yes
# 24            True           True -1.325303 -0.681228      More         Yes
# 25           False           True -1.325303 -0.681228      More         Yes
# 26            True           True -0.562214  0.746701      Less         Yes
# 27           False          False -0.562214  0.746701      Less         Yes
# 28           False          False -0.562214  0.746701      Less         Yes
# 29            True           True -1.557176  0.560300      More         Yes
# ...            ...            ...       ...       ...       ...         ...
# 7106         False          False -0.561359  1.408056      Less         Yes
# 7107         False          False -0.700345  1.210378      Less         Yes
# 7108         False          False -0.700345  1.210378      Less         Yes
# 7109         False          False -1.200930  2.054972      Less         Yes
# 7110          True          False -0.131730  1.590571      Less          No
# 7111         False           True -0.131730  1.590571      Less          No
# 7112          True          False -1.360313  0.847499      Less         Yes
# 7113          True           True -1.360313  0.847499      Less         Yes
# 7114          True           True -1.360313  0.847499      Less         Yes
# 7115          True          False -1.277861 -1.465935      Less         Yes
# 7116         False          False -1.277861 -1.465935      Less         Yes
# 7117         False          False  0.081730  1.495442      Less         Yes
# 7118         False           True  0.081730  1.495442      Less         Yes
# 7119          True           True -0.320826 -0.033613      Less         Yes
# 7120         False          False -0.320826 -0.033613      Less         Yes
# 7121         False          False -0.320826 -0.033613      Less         Yes
# 7122         False          False -0.695899  0.967440      More         Yes
# 7123         False          False -0.695899  0.967440      More         Yes
# 7124          True           True -0.710610  0.121073      More         Yes
# 7125          True           True -0.710610  0.121073      More         Yes
# 7126          True           True -0.710610  0.121073      More         Yes
# 7127         False           True  0.057888  1.311612      More         Yes
# 7128         False          False  0.057888  1.311612      More         Yes
# 7129          True           True  0.057888  1.311612      More         Yes
# 7130          True           True -0.526340 -0.311250      More         Yes
# 7131          True           True -0.526340 -0.311250      More         Yes
# 7132         False           True -0.526340 -0.311250      More         Yes
# 7133          True           True  1.724508  0.757644      More         Yes
# 7134         False          False  1.724508  0.757644      More         Yes
# 7135         False           True  1.724508  0.757644      More         Yes
#
# [7136 rows x 15 columns]

# %%
# reformat data as int: 0,1 
non_bool = [keys[0], keys[4]] + [key for key in keys[11:]]
boolean = [key for key in keys if key not in non_bool] 
#boolean responses automatically transorm to 1 or 0 using int(bool)
for key in boolean:
    data[key] = data[key].astype(int)# = data[key].astype(int)

data["Vignette"] = 0
data["Vignette"][data["Vignette2"] == "More"] = 1

data["played.game"][data["played.game"] == "No"] = 0
data["played.game"][data["played.game"] == "Yes"] = 1
data["party"]=0
data["party"][data["Party"] == "my-party"]= 1


data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#                                              ID  Money  Jobs  Schools  \
# 0     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0     1        0
# 1     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0     1        0
# 2     uuid:10cd1b9a-44d1-44b3-b0b3-85e104efc1ab      0     0        1
# 3     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      1     0        0
# 4     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      0     1        0
# 5     uuid:f9cc85fe-013c-4408-b919-69df3f8d797e      0     1        1
# 6     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0     1        0
# 7     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0     1        0
# 8     uuid:1092f999-7d4a-42d2-bbfa-9cfebe10d595      0     1        0
# 9     uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0     0        1
# 10    uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0     0        0
# 11    uuid:580b6098-6c2f-48c3-b8a9-8968ac1a6137      0     0        0
# 12    uuid:a01cc495-f911-4d23-938a-19c615307b50      1     0        0
# 13    uuid:a01cc495-f911-4d23-938a-19c615307b50      0     0        0
# 16           1      0
# 17           1      0
# 18           0      0
# 19           0      1
# 20           0      0
# 21           1      0
# 22           1      1
# 23           1      0
# 24           1      1
# 25           1      1
# 26           0      0
# 27           0      1
# 28           0      1
# 29           1      0
# ...        ...    ...
# 7106         0      1
# 7107         0      1
# 7108         0      1
# 7109         0      0
# 7110         0      1
# 7111         0      0
# 7112         0      1
# 7113         0      1
# 7114         0      0
# 7115         0      1
# 7116         0      0
# 7117         0      1
# 7118         0      0
# 7119         0      0
# 7120         0      0
# 7121         0      0
# 7122         1      0
# 7123         1      0
# 7124         1      0
# 7125         1      0
# 7126         1      1
# 7127         1      1
# 7128         1      0
# 7129         1      1
# 7130         1      1
# 7131         1      1
# 7132         1      0
# 7133         1      0
# 7134         1      0
# 7135         1      0
#
# [7136 rows x 17 columns]

# %% [markdown]
# # Run regression for each choice

# %%
endog_choice = ["water.choice", "school.choice", "client.choice", "vote.choice"]
exog = ["Money", "Jobs", "Schools", "party", "Woman", "WomanStrong"]
predict_dict = {}
residual_dict = {}
for y in endog_choice:
    Y = data[y]
    X = data[exog]
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    predict_dict[y] =results.predict()
    residual_dict[y] = Y - predict_dict[y]
    print(results.summary())

# %% [markdown]
# # Compare correlation of choices to correaltion of regression residuals and partial correlation of choices

# %%
data[endog_choice].corr()
# Out:
#                water.choice  school.choice  client.choice  vote.choice
# water.choice       1.000000       0.489350      -0.482063     0.605942
# school.choice      0.489350       1.000000      -0.490471     0.646861
# client.choice     -0.482063      -0.490471       1.000000    -0.549888
# vote.choice        0.605942       0.646861      -0.549888     1.000000

# %%
pd.DataFrame(residual_dict).corr()
# Out:
#                water.choice  school.choice  client.choice  vote.choice
# water.choice       1.000000       0.498611      -0.442793     0.592456
# school.choice      0.498611       1.000000      -0.453473     0.616321
# client.choice     -0.442793      -0.453473       1.000000    -0.496578
# vote.choice        0.592456       0.616321      -0.496578     1.000000

# %%
data[endog_choice].pcorr()
# Out:
#                water.choice  school.choice  client.choice  vote.choice
# water.choice       1.000000       0.118770      -0.197035     0.364507
# school.choice      0.118770       1.000000      -0.182565     0.435805
# client.choice     -0.197035      -0.182565       1.000000    -0.247736
# vote.choice        0.364507       0.435805      -0.247736     1.000000

# %%
def gen_pcorr(df, method = "pearson", sig = 0.001):
    # Correlation type:
    # 'pearson': Pearson r product-moment correlation
    # 'spearman': Spearman ρ rank-order correlation
    # 'kendall': Kendall’s τB correlation (for ordinal data)
    # 'bicor': Biweight midcorrelation (robust)
    # 'percbend': Percentage bend correlation (robust)
    # 'shepherd': Shepherd’s pi correlation (robust)
    # 'skipped': Skipped correlation (robust)
    pcs_dct = {}
    for x in df.keys():
        pcs_dct[x]={}
        for y in df.keys():
            # control variables
            # select variables that are not x or y
            other_vars = [z for z in df.keys() if z != y and z != x ]
            if x == y:
                # No need to calculate if the variable is itself
                pcs_dct[x][y] = 1
            else:
                pcs_dct[x][y] = df.partial_corr(x=x,y=y, covar=other_vars,
                                      method=method).round(3)

    return pcs_dct

def save_corr_and_p_vals(pcs_dct):
    corr_dct ={}
    p_vals_dct = {}
    for key in pcs_dct:
        corr_dct[key] ={}
        p_vals_dct[key] = {}
        for key2 in pcs_dct[key]:
            if type(pcs_dct[key][key2]) != int:
                corr_dct[key][key2] =  pcs_dct[key][key2]["r"][0]
                p_vals_dct[key][key2] = pcs_dct[key][key2]["p-val"][0]
            else:
                corr_dct[key][key2] =  1
                p_vals_dct[key][key2] = np.nan
    return corr_dct, p_vals_dct
pcs_dct = gen_pcorr(data[endog_choice].dropna()[:-1], method = "pearson")
corr_dct, p_vals_dct = save_corr_and_p_vals(pcs_dct)

# %% [markdown]
# # Check statistical significance of each partial correlation, plopt statistically significant correlations
#
# It turns out that all partial correlations for choices are statistically significant

# %%
pd.DataFrame(p_vals_dct).sort_index(axis=0, ascending=True).sort_index(axis=1, ascending = True)
# Out:
#                client.choice  school.choice  vote.choice  water.choice
# client.choice            NaN            0.0          0.0           0.0
# school.choice            0.0            NaN          0.0           0.0
# vote.choice              0.0            0.0          NaN           0.0
# water.choice             0.0            0.0          0.0           NaN

# %%
pd.DataFrame(corr_dct).sort_index(axis=0, ascending=True).sort_index(axis=1, ascending = True)
# Out:
#                client.choice  school.choice  vote.choice  water.choice
# client.choice          1.000         -0.182       -0.248        -0.197
# school.choice         -0.182          1.000        0.436         0.119
# vote.choice           -0.248          0.436        1.000         0.365
# water.choice          -0.197          0.119        0.365         1.000

# %%
plt.rcParams['axes.ymargin'] = .1
plt.rcParams['axes.xmargin'] = .1
def graph_pcorr(p_vals_dct, corr_dct, title = "Macro Partial Correlations", sig = .001):

    # initiate graph
    graph = nx.Graph()
    #make list for edges
    edges = []
    # and a list for correlation values to use  as labels
    edge_labels = {}
    for key in p_vals_dct:
        for key2 in p_vals_dct[key]:
            # don't add edge:
            #   1. keys are identical
            #   2. If p-val > sig
            if key != key2  and p_vals_dct[key][key2] <= sig:
                edge = (key.replace(" ","\n"), key2.replace(" ","\n"))
                alt_edge = (edge[1],edge[0])
                # only append if keys are not already in edges as (key2, key)
                if alt_edge not in edges:
                    edges.append(edge)
                    edge_labels[edge] = str(corr_dct[key][key2])

    # edge format: ("i", "j") --> from node i to node j
    graph.add_edges_from(edges)
    # make all nodes in graph blue ("C0")
    color_map = ["C0" for g in graph]
    fig, ax = plt.subplots(figsize = (20,12))
    graph.nodes()
    plt.tight_layout()
    # automatically space nodes
    pos = nx.spring_layout(graph)#, k = 5/(len(sig_corr.keys())**.5))

    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, 
                     with_labels=True,  arrows=False,
                     font_size = 20, alpha = .8,
                     ax = ax)
    nx.draw_networkx_edge_labels(graph,pos,
                                 edge_labels=edge_labels,
                                 font_color='green',
                                 font_size=20)
graph_pcorr(p_vals_dct, corr_dct, "Partial Correlation Structure for Survey Choices")

# %% [markdown]
# # Generate interaction terms and run regression using these in lieu of multivariate

# %%
endog_choice = ["water.choice", "school.choice", "client.choice", "vote.choice"]
exog = ["Money", "Jobs", "Schools", "party", "Woman", "WomanStrong", "Vignette"]
exog = exog +  ["Money X Vignette", "Jobs X Vignette", "Money X Wealth", 
                "Jobs X Wealth", "Vignette X Wealth", "Money X Vignette X Wealth", 
                "Jobs X Vignette X Wealth"]
data["Money X Vignette"] = data["Money"].mul(data["Vignette"])
data["Jobs X Vignette"] = data["Jobs"].mul(data["Vignette"])
data["Money X Wealth"] = data["Money"].mul(data["Wealth"])
data["Jobs X Wealth"] = data["Jobs"].mul(data["Wealth"])
data["Vignette X Wealth"] = data["Vignette"].mul(data["Wealth"])
data["Money X Vignette X Wealth"] = data["Money"].mul(data["Vignette"]).mul(data["Wealth"])
data["Jobs X Vignette X Wealth"] = data["Jobs"].mul(data["Vignette"]).mul(data["Wealth"])

predict_dict = {}
residual_dict = {}
for y in endog_choice:
    Y = data[y]
    X = data[exog]
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    predict_dict[y] =results.predict()
    residual_dict[y] = Y - predict_dict[y]
    print(results.summary())
    print(pd.DataFrame(results.params, list(X.keys())))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           water.choice   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     44.18
# Date:                Wed, 02 Jun 2021   Prob (F-statistic):          1.22e-117
# Time:                        15:25:28   Log-Likelihood:                -4882.1
# No. Observations:                7136   AIC:                             9794.
# Df Residuals:                    7121   BIC:                             9897.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.6127      0.017     36.518      0.000       0.580       0.646
# Money                        -0.2957      0.017    -17.473      0.000      -0.329      -0.263
# Jobs                         -0.0880      0.017     -5.205      0.000      -0.121      -0.055
# Schools                      -0.1115      0.011     -9.806      0.000      -0.134      -0.089
# party                         0.1232      0.011     10.825      0.000       0.101       0.146
# Woman                         0.0163      0.011      1.430      0.153      -0.006       0.039
# WomanStrong                  -0.0005      0.011     -0.047      0.963      -0.023       0.022
# Vignette                     -0.0224      0.021     -1.045      0.296      -0.064       0.020
# Money X Vignette              0.0797      0.030      2.641      0.008       0.021       0.139
# Jobs X Vignette              -0.0066      0.030     -0.221      0.825      -0.065       0.052
# Money X Wealth               -0.0228      0.014     -1.638      0.101      -0.050       0.004
# Jobs X Wealth                 0.0151      0.014      1.088      0.277      -0.012       0.042
# Vignette X Wealth             0.0027      0.020      0.133      0.894      -0.037       0.043
# Money X Vignette X Wealth     0.0443      0.032      1.398      0.162      -0.018       0.106
# Jobs X Vignette X Wealth     -0.0290      0.031     -0.938      0.348      -0.090       0.032
# ==============================================================================
# Omnibus:                    31879.194   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              839.636
# Skew:                          -0.011   Prob(JB):                    4.74e-183
# Kurtosis:                       1.320   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                    0
#  0.612699                      const
# -0.295685                      Money
# -0.088011                       Jobs
# -0.111535                    Schools
#  0.123233                      party
#  0.016267                      Woman
# -0.000533                WomanStrong
# -0.022421                   Vignette
#  0.079737           Money X Vignette
# -0.006618            Jobs X Vignette
# -0.022768             Money X Wealth
#  0.015125              Jobs X Wealth
#  0.002708          Vignette X Wealth
#  0.044266  Money X Vignette X Wealth
# -0.029047   Jobs X Vignette X Wealth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          school.choice   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     61.87
# Date:                Wed, 02 Jun 2021   Prob (F-statistic):          1.49e-165
# Time:                        15:25:28   Log-Likelihood:                -4769.7
# No. Observations:                7136   AIC:                             9569.
# Df Residuals:                    7121   BIC:                             9672.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.4408      0.017     26.692      0.000       0.408       0.473
# Money                        -0.2724      0.017    -16.352      0.000      -0.305      -0.240
# Jobs                         -0.0982      0.017     -5.897      0.000      -0.131      -0.066
# Schools                       0.2218      0.011     19.807      0.000       0.200       0.244
# party                         0.1139      0.011     10.162      0.000       0.092       0.136
# Woman                         0.0241      0.011      2.153      0.031       0.002       0.046
# WomanStrong                   0.0025      0.011      0.222      0.825      -0.019       0.024
# Vignette                     -0.0288      0.021     -1.366      0.172      -0.070       0.013
# Money X Vignette              0.0698      0.030      2.348      0.019       0.012       0.128
# Jobs X Vignette               0.0262      0.030      0.889      0.374      -0.032       0.084
# Money X Wealth               -0.0157      0.014     -1.146      0.252      -0.042       0.011
# Jobs X Wealth                 0.0050      0.014      0.367      0.714      -0.022       0.032
# Vignette X Wealth             0.0137      0.020      0.682      0.495      -0.026       0.053
# Money X Vignette X Wealth     0.0016      0.031      0.050      0.960      -0.060       0.063
# Jobs X Vignette X Wealth     -0.0229      0.030     -0.750      0.453      -0.083       0.037
# ==============================================================================
# Omnibus:                    37640.198   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              731.162
# Skew:                          -0.008   Prob(JB):                    1.70e-159
# Kurtosis:                       1.432   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                    0
#  0.440842                      const
# -0.272399                      Money
# -0.098154                       Jobs
#  0.221770                    Schools
#  0.113873                      party
#  0.024117                      Woman
#  0.002483                WomanStrong
# -0.028845                   Vignette
#  0.069788           Money X Vignette
#  0.026249            Jobs X Vignette
# -0.015675             Money X Wealth
#  0.005025              Jobs X Wealth
#  0.013701          Vignette X Wealth
#  0.001553  Money X Vignette X Wealth
# -0.022862   Jobs X Vignette X Wealth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          client.choice   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     80.70
# Date:                Wed, 02 Jun 2021   Prob (F-statistic):          3.74e-215
# Time:                        15:25:28   Log-Likelihood:                -4653.8
# No. Observations:                7136   AIC:                             9338.
# Df Residuals:                    7121   BIC:                             9441.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.3839      0.016     23.623      0.000       0.352       0.416
# Money                         0.4471      0.016     27.276      0.000       0.415       0.479
# Jobs                          0.1771      0.016     10.816      0.000       0.145       0.209
# Schools                      -0.0307      0.011     -2.782      0.005      -0.052      -0.009
# party                        -0.0852      0.011     -7.727      0.000      -0.107      -0.064
# Woman                        -0.0646      0.011     -5.860      0.000      -0.086      -0.043
# WomanStrong                  -0.0016      0.011     -0.146      0.884      -0.023       0.020
# Vignette                      0.0456      0.021      2.197      0.028       0.005       0.086
# Money X Vignette             -0.0765      0.029     -2.616      0.009      -0.134      -0.019
# Jobs X Vignette              -0.0658      0.029     -2.264      0.024      -0.123      -0.009
# Money X Wealth                0.0140      0.013      1.041      0.298      -0.012       0.040
# Jobs X Wealth                -0.0174      0.013     -1.295      0.195      -0.044       0.009
# Vignette X Wealth            -0.0339      0.020     -1.712      0.087      -0.073       0.005
# Money X Vignette X Wealth     0.0418      0.031      1.361      0.174      -0.018       0.102
# Jobs X Vignette X Wealth      0.0560      0.030      1.865      0.062      -0.003       0.115
# ==============================================================================
# Omnibus:                    59028.667   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              603.230
# Skew:                           0.029   Prob(JB):                    1.02e-131
# Kurtosis:                       1.577   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                    0
#  0.383876                      const
#  0.447055                      Money
#  0.177134                       Jobs
# -0.030650                    Schools
# -0.085193                      party
# -0.064589                      Woman
# -0.001606                WomanStrong
#  0.045647                   Vignette
# -0.076497           Money X Vignette
# -0.065754            Jobs X Vignette
#  0.014021             Money X Wealth
# -0.017448              Jobs X Wealth
# -0.033853          Vignette X Wealth
#  0.041752  Money X Vignette X Wealth
#  0.055963   Jobs X Vignette X Wealth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            vote.choice   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     60.08
# Date:                Wed, 02 Jun 2021   Prob (F-statistic):          9.04e-161
# Time:                        15:25:28   Log-Likelihood:                -4780.9
# No. Observations:                7136   AIC:                             9592.
# Df Residuals:                    7121   BIC:                             9695.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.5144      0.017     31.097      0.000       0.482       0.547
# Money                        -0.3431      0.017    -20.567      0.000      -0.376      -0.310
# Jobs                         -0.1021      0.017     -6.126      0.000      -0.135      -0.069
# Schools                       0.0983      0.011      8.763      0.000       0.076       0.120
# party                         0.1312      0.011     11.687      0.000       0.109       0.153
# Woman                         0.0337      0.011      3.003      0.003       0.012       0.056
# WomanStrong                   0.0017      0.011      0.149      0.881      -0.020       0.024
# Vignette                     -0.0244      0.021     -1.156      0.248      -0.066       0.017
# Money X Vignette              0.0563      0.030      1.892      0.059      -0.002       0.115
# Jobs X Vignette               0.0234      0.030      0.793      0.428      -0.035       0.081
# Money X Wealth               -0.0191      0.014     -1.391      0.164      -0.046       0.008
# Jobs X Wealth                 0.0141      0.014      1.029      0.304      -0.013       0.041
# Vignette X Wealth             0.0263      0.020      1.305      0.192      -0.013       0.066
# Money X Vignette X Wealth    -0.0310      0.031     -0.994      0.320      -0.092       0.030
# Jobs X Vignette X Wealth     -0.0336      0.031     -1.101      0.271      -0.093       0.026
# ==============================================================================
# Omnibus:                    37364.180   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              735.419
# Skew:                          -0.022   Prob(JB):                    2.02e-160
# Kurtosis:                       1.428   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                    0
#  0.514405                      const
# -0.343146                      Money
# -0.102125                       Jobs
#  0.098272                    Schools
#  0.131167                      party
#  0.033695                      Woman
#  0.001673                WomanStrong
# -0.024444                   Vignette
#  0.056300           Money X Vignette
#  0.023434            Jobs X Vignette
# -0.019058             Money X Wealth
#  0.014102              Jobs X Wealth
#  0.026269          Vignette X Wealth
# -0.031030  Money X Vignette X Wealth
# -0.033619   Jobs X Vignette X Wealth

# %%
pd.DataFrame(residual_dict).corr()
# Out:
#                water.choice  school.choice  client.choice  vote.choice
# water.choice       1.000000       0.498138      -0.442820     0.592581
# school.choice      0.498138       1.000000      -0.453014     0.616080
# client.choice     -0.442820      -0.453014       1.000000    -0.495927
# vote.choice        0.592581       0.616080      -0.495927     1.000000
